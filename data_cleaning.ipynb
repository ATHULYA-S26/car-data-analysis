# %% [markdown]
# # car data analysis

# %%
import pandas as pd
df=pd.read_csv("Car details v3 - Car details v3.csv")
print(df)
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8123             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126               Tata Indigo CR4  2013         290000      25000  Diesel
# 8127               Tata Indigo CR4  2013         290000      25000  Diesel
#
#      seller_type transmission                 owner     mileage   engine  \
# 0     Individual       Manual           First Owner   23.4 kmpl  1248 CC
# 1     Individual       Manual          Second Owner  21.14 kmpl  1498 CC
# 2     Individual       Manual           Third Owner   17.7 kmpl  1497 CC
# 3     Individual       Manual           First Owner   23.0 kmpl  1396 CC
# 4     Individual       Manual           First Owner   16.1 kmpl  1298 CC
# ...          ...          ...                   ...         ...      ...
# 8123  Individual       Manual           First Owner   18.5 kmpl  1197 CC
# 8124  Individual       Manual  Fourth & Above Owner   16.8 kmpl  1493 CC
# 8125  Individual       Manual           First Owner   19.3 kmpl  1248 CC
# 8126  Individual       Manual           First Owner  23.57 kmpl  1396 CC
# 8127  Individual       Manual           First Owner  23.57 kmpl  1396 CC
#
#        max_power                     torque  seats
# 0         74 bhp             190Nm@ 2000rpm    5.0
# 1     103.52 bhp        250Nm@ 1500-2500rpm    5.0
# 2         78 bhp      12.7@ 2,700(kgm@ rpm)    5.0
# 3         90 bhp   22.4 kgm at 1750-2750rpm    5.0
# 4       88.2 bhp      11.5@ 4,500(kgm@ rpm)    5.0
# ...          ...                        ...    ...
# 8123   82.85 bhp           113.7Nm@ 4000rpm    5.0
# 8124     110 bhp  24@ 1,900-2,750(kgm@ rpm)    5.0
# 8125    73.9 bhp             190Nm@ 2000rpm    5.0
# 8126      70 bhp        140Nm@ 1800-3000rpm    5.0
# 8127      70 bhp        140Nm@ 1800-3000rpm    5.0
#
# [8128 rows x 13 columns]

# %% [markdown]
# ## identify the details of data

# %%
df.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# 1       250Nm@ 1500-2500rpm    5.0
# 2     12.7@ 2,700(kgm@ rpm)    5.0
# 3  22.4 kgm at 1750-2750rpm    5.0
# 4     11.5@ 4,500(kgm@ rpm)    5.0

# %%
df.tail()
# Out:
#                         name  year  selling_price  km_driven    fuel  \
# 8123       Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124   Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125  Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126         Tata Indigo CR4  2013         290000      25000  Diesel
# 8127         Tata Indigo CR4  2013         290000      25000  Diesel
#
#      seller_type transmission                 owner     mileage   engine  \
# 8123  Individual       Manual           First Owner   18.5 kmpl  1197 CC
# 8124  Individual       Manual  Fourth & Above Owner   16.8 kmpl  1493 CC
# 8125  Individual       Manual           First Owner   19.3 kmpl  1248 CC
# 8126  Individual       Manual           First Owner  23.57 kmpl  1396 CC
# 8127  Individual       Manual           First Owner  23.57 kmpl  1396 CC
#
#       max_power                     torque  seats
# 8123  82.85 bhp           113.7Nm@ 4000rpm    5.0
# 8124    110 bhp  24@ 1,900-2,750(kgm@ rpm)    5.0
# 8125   73.9 bhp             190Nm@ 2000rpm    5.0
# 8126     70 bhp        140Nm@ 1800-3000rpm    5.0
# 8127     70 bhp        140Nm@ 1800-3000rpm    5.0

# %%
df.sample(5)
# Out:
#                                    name  year  selling_price  km_driven  \
# 5548   Maruti Swift Dzire AMT VXI BS IV  2019         700000      45000
# 2231  Skoda Rapid 1.6 MPI Ambition BSIV  2019         725000      25000
# 5490     Tata Indigo CS LX (TDI) BS III  2013         140000     100000
# 5603    Tata Nexon 1.2 Revotron XZ Plus  2018         850000      40000
# 6911                 Hyundai Accent GLE  2009         180000      87000
#
#         fuel seller_type transmission         owner     mileage   engine  \
# 5548  Petrol  Individual    Automatic   First Owner   22.0 kmpl  1197 CC
# 2231  Petrol  Individual       Manual   First Owner  15.41 kmpl  1598 CC
# 5490  Diesel  Individual       Manual   First Owner  19.09 kmpl  1396 CC
# 5603  Petrol  Individual       Manual  Second Owner   17.0 kmpl  1198 CC
# 6911  Petrol  Individual       Manual  Second Owner   13.2 kmpl  1495 CC
#
#       max_power                 torque  seats
# 5548  81.80 bhp         113Nm@ 4200rpm    5.0
# 2231  103.2 bhp    153Nm@ 3750-3800rpm    5.0
# 5490     69 bhp         135Nm@ 2500rpm    5.0
# 5603  108.5 bhp    170Nm@ 1750-4000rpm    5.0
# 6911     94 bhp  12.5@ 3,500(kgm@ rpm)    5.0

# %%
df.shape
# Out:
# (8128, 13)

# %%
df.columns
# Out:
# Index(['name', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner', 'mileage', 'engine', 'max_power', 'torque',
#        'seats'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8128 entries, 0 to 8127
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           8128 non-null   object
#  1   year           8128 non-null   int64
#  2   selling_price  8128 non-null   int64
#  3   km_driven      8128 non-null   int64
#  4   fuel           8128 non-null   object
#  5   seller_type    8128 non-null   object
#  6   transmission   8128 non-null   object
#  7   owner          8128 non-null   object
#  8   mileage        7907 non-null   object
#  9   engine         7907 non-null   object
#  10  max_power      7913 non-null   object
#  11  torque         7906 non-null   object
#  12  seats          7907 non-null   float64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 825.6+ KB

# %%
df.dtypes
# Out:
# name              object
# year               int64
# selling_price      int64
# km_driven          int64
# fuel              object
# seller_type       object
# transmission      object
# owner             object
# mileage           object
# engine            object
# max_power         object
# torque            object
# seats            float64
# dtype: object

# %% [markdown]
# row function of data

# %%
df.iloc[2]
# Out:
# name             Honda City 2017-2020 EXi
# year                                 2006
# selling_price                      158000
# km_driven                          140000
# fuel                               Petrol
# seller_type                    Individual
# transmission                       Manual
# owner                         Third Owner
# mileage                         17.7 kmpl
# engine                            1497 CC
# max_power                          78 bhp
# torque              12.7@ 2,700(kgm@ rpm)
# seats                                 5.0
# Name: 2, dtype: object

# %%
df.isnull().sum()
# Out:
# name               0
# year               0
# selling_price      0
# km_driven          0
# fuel               0
# seller_type        0
# transmission       0
# owner              0
# mileage          221
# engine           221
# max_power        215
# torque           222
# seats            221
# dtype: int64

# %%
df.dropna()
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8123             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126               Tata Indigo CR4  2013         290000      25000  Diesel
# 8127               Tata Indigo CR4  2013         290000      25000  Diesel
#
#      seller_type transmission                 owner     mileage   engine  \
# 0     Individual       Manual           First Owner   23.4 kmpl  1248 CC
# 1     Individual       Manual          Second Owner  21.14 kmpl  1498 CC
# 2     Individual       Manual           Third Owner   17.7 kmpl  1497 CC
# 3     Individual       Manual           First Owner   23.0 kmpl  1396 CC
# 4     Individual       Manual           First Owner   16.1 kmpl  1298 CC
# ...          ...          ...                   ...         ...      ...
# 8123  Individual       Manual           First Owner   18.5 kmpl  1197 CC
# 8124  Individual       Manual  Fourth & Above Owner   16.8 kmpl  1493 CC
# 8125  Individual       Manual           First Owner   19.3 kmpl  1248 CC
# 8126  Individual       Manual           First Owner  23.57 kmpl  1396 CC
# 8127  Individual       Manual           First Owner  23.57 kmpl  1396 CC
#
#        max_power                     torque  seats
# 0         74 bhp             190Nm@ 2000rpm    5.0
# 1     103.52 bhp        250Nm@ 1500-2500rpm    5.0
# 2         78 bhp      12.7@ 2,700(kgm@ rpm)    5.0
# 3         90 bhp   22.4 kgm at 1750-2750rpm    5.0
# 4       88.2 bhp      11.5@ 4,500(kgm@ rpm)    5.0
# ...          ...                        ...    ...
# 8123   82.85 bhp           113.7Nm@ 4000rpm    5.0
# 8124     110 bhp  24@ 1,900-2,750(kgm@ rpm)    5.0
# 8125    73.9 bhp             190Nm@ 2000rpm    5.0
# 8126      70 bhp        140Nm@ 1800-3000rpm    5.0
# 8127      70 bhp        140Nm@ 1800-3000rpm    5.0
#
# [7906 rows x 13 columns]

# %%
df.duplicated().sum()
# Out:
# np.int64(1202)

# %%
df[df.duplicated()]
# Out:
#                                           name  year  selling_price  \
# 291                   Hyundai Grand i10 Sportz  2017         450000
# 296                           Maruti Swift VXI  2012         330000
# 370   Jaguar XE 2016-2019 2.0L Diesel Prestige  2017        2625000
# 371                              Lexus ES 300h  2019        5150000
# 372             Jaguar XF 2.0 Diesel Portfolio  2017        3200000
# ...                                        ...   ...            ...
# 7987             Renault Captur 1.5 Diesel RXT  2018        1265000
# 7988                  Maruti Ciaz Alpha Diesel  2019        1025000
# 8117                    Maruti Swift Dzire VDI  2015         625000
# 8126                           Tata Indigo CR4  2013         290000
# 8127                           Tata Indigo CR4  2013         290000
#
#       km_driven    fuel seller_type transmission         owner     mileage  \
# 291       35000  Petrol  Individual       Manual   First Owner   18.9 kmpl
# 296       50000  Petrol  Individual       Manual  Second Owner   18.6 kmpl
# 370        9000  Diesel      Dealer    Automatic   First Owner   13.6 kmpl
# 371       20000  Petrol      Dealer    Automatic   First Owner  22.37 kmpl
# 372       45000  Diesel      Dealer    Automatic   First Owner  19.33 kmpl
# ...         ...     ...         ...          ...           ...         ...
# 7987      12000  Diesel  Individual       Manual   First Owner  20.37 kmpl
# 7988      32000  Diesel  Individual       Manual   First Owner  28.09 kmpl
# 8117      50000  Diesel  Individual       Manual   First Owner  26.59 kmpl
# 8126      25000  Diesel  Individual       Manual   First Owner  23.57 kmpl
# 8127      25000  Diesel  Individual       Manual   First Owner  23.57 kmpl
#
#        engine   max_power               torque  seats
# 291   1197 CC      82 bhp       114Nm@ 4000rpm    5.0
# 296   1197 CC    85.8 bhp       114Nm@ 4000rpm    5.0
# 370   1999 CC     177 bhp  430Nm@ 1750-2500rpm    5.0
# 371   2487 CC  214.56 bhp  202Nm@ 3600-5200rpm    5.0
# 372   1999 CC     177 bhp  430Nm@ 1750-2500rpm    5.0
# ...       ...         ...                  ...    ...
# 7987  1461 CC  108.45 bhp       240Nm@ 1750rpm    5.0
# 7988  1248 CC   88.50 bhp       200Nm@ 1750rpm    5.0
# 8117  1248 CC      74 bhp       190Nm@ 2000rpm    5.0
# 8126  1396 CC      70 bhp  140Nm@ 1800-3000rpm    5.0
# 8127  1396 CC      70 bhp  140Nm@ 1800-3000rpm    5.0
#
# [1202 rows x 13 columns]

# %%
duplicates=df[df.duplicated()]

# %%
duplicates.sort_values(by="name")
# Out:
#                                       name  year  selling_price  km_driven  \
# 7324  Audi Q3 2.0 TDI Quattro Premium Plus  2017        2825000      22000
# 7775               Audi Q5 3.0 TDI Quattro  2014        1850000      76131
# 5245            Audi Q5 35TDI Premium Plus  2018        3975000      31800
# 1561            Audi Q5 35TDI Premium Plus  2018        3975000      31800
# 3236            Audi Q5 35TDI Premium Plus  2018        3975000      31800
# ...                                    ...   ...            ...        ...
# 1828        Volvo XC40 D4 Inscription BSIV  2019        3800000      20000
# 6693        Volvo XC40 D4 Inscription BSIV  2019        3800000      20000
# 4219        Volvo XC40 D4 Inscription BSIV  2019        3800000      20000
# 1100        Volvo XC40 D4 Inscription BSIV  2019        3800000      20000
# 3251                Volvo XC40 D4 R-Design  2018        3400000      22000
#
#         fuel seller_type transmission        owner     mileage   engine  \
# 7324  Diesel      Dealer    Automatic  First Owner  15.73 kmpl  1968 CC
# 7775  Diesel  Individual    Automatic  First Owner  13.22 kmpl  2967 CC
# 5245  Diesel      Dealer    Automatic  First Owner  17.01 kmpl  1968 CC
# 1561  Diesel      Dealer    Automatic  First Owner  17.01 kmpl  1968 CC
# 3236  Diesel      Dealer    Automatic  First Owner  17.01 kmpl  1968 CC
# ...      ...         ...          ...          ...         ...      ...
# 1828  Diesel  Individual    Automatic  First Owner   18.0 kmpl  1969 CC
# 6693  Diesel  Individual    Automatic  First Owner   18.0 kmpl  1969 CC
# 4219  Diesel  Individual    Automatic  First Owner   18.0 kmpl  1969 CC
# 1100  Diesel  Individual    Automatic  First Owner   18.0 kmpl  1969 CC
# 3251  Diesel      Dealer    Automatic  First Owner   18.0 kmpl  1969 CC
#
#        max_power               torque  seats
# 7324  174.33 bhp  380Nm@ 1750-2500rpm    5.0
# 7775   241.4 bhp  580Nm@ 1400-3250rpm    5.0
# 5245     188 bhp  400nm@ 1750-3000rpm    5.0
# 1561     188 bhp  400nm@ 1750-3000rpm    5.0
# 3236     188 bhp  400nm@ 1750-3000rpm    5.0
# ...          ...                  ...    ...
# 1828     190 bhp                400Nm    5.0
# 6693     190 bhp                400Nm    5.0
# 4219     190 bhp                400Nm    5.0
# 1100     190 bhp                400Nm    5.0
# 3251     190 bhp                400Nm    5.0
#
# [1202 rows x 13 columns]

# %%
df=df.drop_duplicates()

# %%
df
# Out:
#                                    name  year  selling_price  km_driven  \
# 0                Maruti Swift Dzire VDI  2014         450000     145500
# 1          Skoda Rapid 1.5 TDI Ambition  2014         370000     120000
# 2              Honda City 2017-2020 EXi  2006         158000     140000
# 3             Hyundai i20 Sportz Diesel  2010         225000     127000
# 4                Maruti Swift VXI BSIII  2007         130000     120000
# ...                                 ...   ...            ...        ...
# 8121  Maruti Wagon R VXI BS IV with ABS  2013         260000      50000
# 8122         Hyundai i20 Magna 1.4 CRDi  2014         475000      80000
# 8123                  Hyundai i20 Magna  2013         320000     110000
# 8124              Hyundai Verna CRDi SX  2007         135000     119000
# 8125             Maruti Swift Dzire ZDi  2009         382000     120000
#
#         fuel seller_type transmission                 owner     mileage  \
# 0     Diesel  Individual       Manual           First Owner   23.4 kmpl
# 1     Diesel  Individual       Manual          Second Owner  21.14 kmpl
# 2     Petrol  Individual       Manual           Third Owner   17.7 kmpl
# 3     Diesel  Individual       Manual           First Owner   23.0 kmpl
# 4     Petrol  Individual       Manual           First Owner   16.1 kmpl
# ...      ...         ...          ...                   ...         ...
# 8121  Petrol  Individual       Manual          Second Owner   18.9 kmpl
# 8122  Diesel  Individual       Manual          Second Owner  22.54 kmpl
# 8123  Petrol  Individual       Manual           First Owner   18.5 kmpl
# 8124  Diesel  Individual       Manual  Fourth & Above Owner   16.8 kmpl
# 8125  Diesel  Individual       Manual           First Owner   19.3 kmpl
#
#        engine   max_power                     torque  seats
# 0     1248 CC      74 bhp             190Nm@ 2000rpm    5.0
# 1     1498 CC  103.52 bhp        250Nm@ 1500-2500rpm    5.0
# 2     1497 CC      78 bhp      12.7@ 2,700(kgm@ rpm)    5.0
# 3     1396 CC      90 bhp   22.4 kgm at 1750-2750rpm    5.0
# 4     1298 CC    88.2 bhp      11.5@ 4,500(kgm@ rpm)    5.0
# ...       ...         ...                        ...    ...
# 8121   998 CC    67.1 bhp              90Nm@ 3500rpm    5.0
# 8122  1396 CC   88.73 bhp      219.7Nm@ 1500-2750rpm    5.0
# 8123  1197 CC   82.85 bhp           113.7Nm@ 4000rpm    5.0
# 8124  1493 CC     110 bhp  24@ 1,900-2,750(kgm@ rpm)    5.0
# 8125  1248 CC    73.9 bhp             190Nm@ 2000rpm    5.0
#
# [6926 rows x 13 columns]

# %% [markdown]
# separate the value and unit into distint coloumns

# %%
df[["mileage_value","mileage_unit"]]=df["mileage"].str.split(" ",expand=True)

# %%
df
# Out:
#                                    name  year  selling_price  km_driven  \
# 0                Maruti Swift Dzire VDI  2014         450000     145500
# 1          Skoda Rapid 1.5 TDI Ambition  2014         370000     120000
# 2              Honda City 2017-2020 EXi  2006         158000     140000
# 3             Hyundai i20 Sportz Diesel  2010         225000     127000
# 4                Maruti Swift VXI BSIII  2007         130000     120000
# ...                                 ...   ...            ...        ...
# 8121  Maruti Wagon R VXI BS IV with ABS  2013         260000      50000
# 8122         Hyundai i20 Magna 1.4 CRDi  2014         475000      80000
# 8123                  Hyundai i20 Magna  2013         320000     110000
# 8124              Hyundai Verna CRDi SX  2007         135000     119000
# 8125             Maruti Swift Dzire ZDi  2009         382000     120000
#
#         fuel seller_type transmission                 owner     mileage  \
# 0     Diesel  Individual       Manual           First Owner   23.4 kmpl
# 1     Diesel  Individual       Manual          Second Owner  21.14 kmpl
# 2     Petrol  Individual       Manual           Third Owner   17.7 kmpl
# 3     Diesel  Individual       Manual           First Owner   23.0 kmpl
# 4     Petrol  Individual       Manual           First Owner   16.1 kmpl
# ...      ...         ...          ...                   ...         ...
# 8121  Petrol  Individual       Manual          Second Owner   18.9 kmpl
# 8122  Diesel  Individual       Manual          Second Owner  22.54 kmpl
# 8123  Petrol  Individual       Manual           First Owner   18.5 kmpl
# 8124  Diesel  Individual       Manual  Fourth & Above Owner   16.8 kmpl
# 8125  Diesel  Individual       Manual           First Owner   19.3 kmpl
#
#        engine   max_power                     torque  seats mileage_value  \
# 0     1248 CC      74 bhp             190Nm@ 2000rpm    5.0          23.4
# 1     1498 CC  103.52 bhp        250Nm@ 1500-2500rpm    5.0         21.14
# 2     1497 CC      78 bhp      12.7@ 2,700(kgm@ rpm)    5.0          17.7
# 3     1396 CC      90 bhp   22.4 kgm at 1750-2750rpm    5.0          23.0
# 4     1298 CC    88.2 bhp      11.5@ 4,500(kgm@ rpm)    5.0          16.1
# ...       ...         ...                        ...    ...           ...
# 8121   998 CC    67.1 bhp              90Nm@ 3500rpm    5.0          18.9
# 8122  1396 CC   88.73 bhp      219.7Nm@ 1500-2750rpm    5.0         22.54
# 8123  1197 CC   82.85 bhp           113.7Nm@ 4000rpm    5.0          18.5
# 8124  1493 CC     110 bhp  24@ 1,900-2,750(kgm@ rpm)    5.0          16.8
# 8125  1248 CC    73.9 bhp             190Nm@ 2000rpm    5.0          19.3
#
#      mileage_unit
# 0            kmpl
# 1            kmpl
# 2            kmpl
# 3            kmpl
# 4            kmpl
# ...           ...
# 8121         kmpl
# 8122         kmpl
# 8123         kmpl
# 8124         kmpl
# 8125         kmpl
#
# [6926 rows x 15 columns]

# %%
df[["engine_value","engine_unit"]]=df["engine"].str.split(" ",expand=True)

# %%
df
# Out:
#                                    name  year  selling_price  km_driven  \
# 0                Maruti Swift Dzire VDI  2014         450000     145500
# 1          Skoda Rapid 1.5 TDI Ambition  2014         370000     120000
# 2              Honda City 2017-2020 EXi  2006         158000     140000
# 3             Hyundai i20 Sportz Diesel  2010         225000     127000
# 4                Maruti Swift VXI BSIII  2007         130000     120000
# ...                                 ...   ...            ...        ...
# 8121  Maruti Wagon R VXI BS IV with ABS  2013         260000      50000
# 8122         Hyundai i20 Magna 1.4 CRDi  2014         475000      80000
# 8123                  Hyundai i20 Magna  2013         320000     110000
# 8124              Hyundai Verna CRDi SX  2007         135000     119000
# 8125             Maruti Swift Dzire ZDi  2009         382000     120000
#
#         fuel seller_type transmission                 owner     mileage  \
# 0     Diesel  Individual       Manual           First Owner   23.4 kmpl
# 1     Diesel  Individual       Manual          Second Owner  21.14 kmpl
# 2     Petrol  Individual       Manual           Third Owner   17.7 kmpl
# 3     Diesel  Individual       Manual           First Owner   23.0 kmpl
# 4     Petrol  Individual       Manual           First Owner   16.1 kmpl
# ...      ...         ...          ...                   ...         ...
# 8121  Petrol  Individual       Manual          Second Owner   18.9 kmpl
# 8122  Diesel  Individual       Manual          Second Owner  22.54 kmpl
# 8123  Petrol  Individual       Manual           First Owner   18.5 kmpl
# 8124  Diesel  Individual       Manual  Fourth & Above Owner   16.8 kmpl
# 8125  Diesel  Individual       Manual           First Owner   19.3 kmpl
#
#        engine   max_power                     torque  seats mileage_value  \
# 0     1248 CC      74 bhp             190Nm@ 2000rpm    5.0          23.4
# 1     1498 CC  103.52 bhp        250Nm@ 1500-2500rpm    5.0         21.14
# 2     1497 CC      78 bhp      12.7@ 2,700(kgm@ rpm)    5.0          17.7
# 3     1396 CC      90 bhp   22.4 kgm at 1750-2750rpm    5.0          23.0
# 4     1298 CC    88.2 bhp      11.5@ 4,500(kgm@ rpm)    5.0          16.1
# ...       ...         ...                        ...    ...           ...
# 8121   998 CC    67.1 bhp              90Nm@ 3500rpm    5.0          18.9
# 8122  1396 CC   88.73 bhp      219.7Nm@ 1500-2750rpm    5.0         22.54
# 8123  1197 CC   82.85 bhp           113.7Nm@ 4000rpm    5.0          18.5
# 8124  1493 CC     110 bhp  24@ 1,900-2,750(kgm@ rpm)    5.0          16.8
# 8125  1248 CC    73.9 bhp             190Nm@ 2000rpm    5.0          19.3
#
#      mileage_unit engine_value engine_unit
# 0            kmpl         1248          CC
# 1            kmpl         1498          CC
# 2            kmpl         1497          CC
# 3            kmpl         1396          CC
# 4            kmpl         1298          CC
# ...           ...          ...         ...
# 8121         kmpl          998          CC
# 8122         kmpl         1396          CC
# 8123         kmpl         1197          CC
# 8124         kmpl         1493          CC
# 8125         kmpl         1248          CC
#
# [6926 rows x 17 columns]

# %%
df.astype({"mileage_value":"float","engine_value":"float"})
# Out:
#                                    name  year  selling_price  km_driven  \
# 0                Maruti Swift Dzire VDI  2014         450000     145500
# 1          Skoda Rapid 1.5 TDI Ambition  2014         370000     120000
# 2              Honda City 2017-2020 EXi  2006         158000     140000
# 3             Hyundai i20 Sportz Diesel  2010         225000     127000
# 4                Maruti Swift VXI BSIII  2007         130000     120000
# ...                                 ...   ...            ...        ...
# 8121  Maruti Wagon R VXI BS IV with ABS  2013         260000      50000
# 8122         Hyundai i20 Magna 1.4 CRDi  2014         475000      80000
# 8123                  Hyundai i20 Magna  2013         320000     110000
# 8124              Hyundai Verna CRDi SX  2007         135000     119000
# 8125             Maruti Swift Dzire ZDi  2009         382000     120000
#
#         fuel seller_type transmission                 owner     mileage  \
# 0     Diesel  Individual       Manual           First Owner   23.4 kmpl
# 1     Diesel  Individual       Manual          Second Owner  21.14 kmpl
# 2     Petrol  Individual       Manual           Third Owner   17.7 kmpl
# 3     Diesel  Individual       Manual           First Owner   23.0 kmpl
# 4     Petrol  Individual       Manual           First Owner   16.1 kmpl
# ...      ...         ...          ...                   ...         ...
# 8121  Petrol  Individual       Manual          Second Owner   18.9 kmpl
# 8122  Diesel  Individual       Manual          Second Owner  22.54 kmpl
# 8123  Petrol  Individual       Manual           First Owner   18.5 kmpl
# 8124  Diesel  Individual       Manual  Fourth & Above Owner   16.8 kmpl
# 8125  Diesel  Individual       Manual           First Owner   19.3 kmpl
#
#        engine   max_power                     torque  seats  mileage_value  \
# 0     1248 CC      74 bhp             190Nm@ 2000rpm    5.0          23.40
# 1     1498 CC  103.52 bhp        250Nm@ 1500-2500rpm    5.0          21.14
# 2     1497 CC      78 bhp      12.7@ 2,700(kgm@ rpm)    5.0          17.70
# 3     1396 CC      90 bhp   22.4 kgm at 1750-2750rpm    5.0          23.00
# 4     1298 CC    88.2 bhp      11.5@ 4,500(kgm@ rpm)    5.0          16.10
# ...       ...         ...                        ...    ...            ...
# 8121   998 CC    67.1 bhp              90Nm@ 3500rpm    5.0          18.90
# 8122  1396 CC   88.73 bhp      219.7Nm@ 1500-2750rpm    5.0          22.54
# 8123  1197 CC   82.85 bhp           113.7Nm@ 4000rpm    5.0          18.50
# 8124  1493 CC     110 bhp  24@ 1,900-2,750(kgm@ rpm)    5.0          16.80
# 8125  1248 CC    73.9 bhp             190Nm@ 2000rpm    5.0          19.30
#
#      mileage_unit  engine_value engine_unit
# 0            kmpl        1248.0          CC
# 1            kmpl        1498.0          CC
# 2            kmpl        1497.0          CC
# 3            kmpl        1396.0          CC
# 4            kmpl        1298.0          CC
# ...           ...           ...         ...
# 8121         kmpl         998.0          CC
# 8122         kmpl        1396.0          CC
# 8123         kmpl        1197.0          CC
# 8124         kmpl        1493.0          CC
# 8125         kmpl        1248.0          CC
#
# [6926 rows x 17 columns]

# %%
df["selling_price"].mean()
# Out:
# np.float64(517270.6784579844)

# %%
df["selling_price"].median()
# Out:
# 400000.0

# %%
df["selling_price"].min()
# Out:
# 29999

# %%
df["selling_price"].max
# Out:
# <bound method Series.max of 0       450000
# 1       370000
# 2       158000
# 3       225000
# 4       130000
#          ...
# 8121    260000
# 8122    475000
# 8123    320000
# 8124    135000
# 8125    382000
# Name: selling_price, Length: 6926, dtype: int64>

# %%
df["km_driven"].mean()
# Out:
# np.float64(73995.67643661566)

# %%
df["km_driven"].median()
# Out:
# 70000.0

# %%
df["km_driven"].max()
# Out:
# 2360457

# %%
df["km_driven"].min()
# Out:
# 1

# %%
df["km_driven"].mode()
# Out:
# 0    120000
# Name: km_driven, dtype: int64

# %%
df["selling_price"].mode()
# Out:
# 0    300000
# Name: selling_price, dtype: int64
